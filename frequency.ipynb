# %%
# All repetation is frequncy ( tell how many times repects)
# Relative frequncy is percentage value 
# Cumulative Relative Frequence is sum of previous relation frequences

# %%
import pandas as pd
import numpy as np
from Univariate import Univariate

# %%
dataset = pd.read_csv("data.csv")
dataset
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
freqTable = Univariate.frequency(dataset)
freqTable
# Out:
# 4600
#    Unique_Values  Frequency  Relative_Frequency    Cumsum
# 0            3.0       2032            0.441739  0.441739
# 1            4.0       1531            0.332826  0.774565
# 2            2.0        566            0.123043  0.897609
# 3            5.0        353            0.076739  0.974348
# 4            6.0         61            0.013261  0.987609
# 5            1.0         38            0.008261  0.995870
# 6            7.0         14            0.003043  0.998913
# 7            8.0          2            0.000435  0.999348
# 8            0.0          2            0.000435  0.999783
# 9            9.0          1            0.000217  1.000000
